# %%
# 1) Import
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# 2) Infos
house_pricing = pd.read_csv('data/house_pricing.csv')
house_pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_pricing
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# 3)
ax = sns.scatterplot(x='LotArea', y='SalePrice', data=house_pricing, color='red')
#ax.set(xlabel='LotArea', ylabel='SalePrice')
plt.show()

# %%
# 4)
df_housing_prices = pd.DataFrame(house_pricing)
df_cleaned0 = df_housing_prices[ df_housing_prices['LotArea'] < 20000 ]
df_cleaned1 = df_cleaned0[ df_cleaned0['SalePrice'] < 500000 ]
df_cleaned1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
ax = sns.relplot(x='LotArea', y='SalePrice', data=df_cleaned1, color='red')

# %%
# 5)
frontage_area = sns.relplot(x='LotArea', y='LotFrontage', data=df_cleaned1)

# %%
# 6)
df_cleaned2 = df_cleaned1[ df_cleaned1['LotArea'] < 100000 ]
df_cleaned3 = df_cleaned2[ df_cleaned2['LotFrontage'] < 200 ]
frontage_area = sns.relplot(x='LotArea', y='LotFrontage', data=df_cleaned3)

# %%
#Visualisation de relations continues :

# %%
# 1)
sales_predictions = pd.read_csv('data/sales_predictions.csv')
sales_predictions.info()
sns.l
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
# 2)
price_over_time = sns.relplot(x='date', y='item_price', data=sales_predictions)
plt.show()

# %%
# On ne peut pas voir grand chose à cause d'un point extréme (prix > 30000 !)

# %%
# 3)
sales_predictions_sample = pd.DataFrame(sales_predictions).sample(n=50)
sales_predictions_sample
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 811379   02.08.2013               7       30     5594     1190.00
# 1311477  02.01.2014              12       42     8541      299.00
# 1305341  04.01.2014              12       30    18211      199.00
# 2346082  18.01.2015              24       26    14439      149.00
# 2433043  27.02.2015              25       56     6501      249.50
# 1229368  26.12.2013              11       57    12104      529.00
# 2351549  30.01.2015              24       25     1556     2999.00
# 672321   01.07.2013               6        3     6910      899.00
# 859434   18.09.2013               8       17    14440      299.00
# 1212838  23.12.2013              11       51    18837      195.00
# 163955   20.02.2013               1        4     2441      599.50
# 1874733  18.08.2014              19       48     7808     2599.00
# 2788491  12.08.2015              31       38    14678      229.00
# ...

# %%
price_over_time_sample = sns.relplot(x='date', y='item_price', data=sales_predictions_sample)
plt.show()

# %%
# 4)
price_over_time_sample2 = sns.relplot(x='date', y='item_price', data=pd.DataFrame(sales_predictions).sample(n=100))

# %%
# 5)
sales_predictions_sample['date'] = pd.to_datetime(sales_predictions_sample['date']) 
sales_predictions_sample
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 811379  2013-02-08               7       30     5594     1190.00           1.0
# 1311477 2014-02-01              12       42     8541      299.00           1.0
# 1305341 2014-04-01              12       30    18211      199.00           1.0
# 2346082 2015-01-18              24       26    14439      149.00           1.0
# 2433043 2015-02-27              25       56     6501      249.50           1.0
# 1229368 2013-12-26              11       57    12104      529.00           2.0
# 2351549 2015-01-30              24       25     1556     2999.00           2.0
# 672321  2013-01-07               6        3     6910      899.00           1.0
# 859434  2013-09-18               8       17    14440      299.00           1.0
# 1212838 2013-12-23              11       51    18837      195.00           1.0
# 163955  2013-02-20               1        4     2441      599.50           1.0
# ...

# %%
# 6)
price_over_time_sample = sns.relplot(x='date', y='item_price', data=sales_predictions_sample)
plt.show()

# %%
# Visualisation de variables catégoriques :

# %%
# 1)
ibm_hr_attrition = pd.read_csv('data/ibm_hr_attrition.csv')
ibm_hr_attrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
ibm_hr_attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_attrition = pd.DataFrame(ibm_hr_attrition)
df_attrition = df_attrition[ df_attrition['Attrition']=='Yes' ]

# %%
g = sns.catplot(x="JobSatisfaction", kind='count', data=df_attrition)

# %%
# 3)
g = sns.boxplot(x="JobSatisfaction", y='Attrition', data=ibm_hr_attrition)

# %%
# 4) Le Boxplot n'est pas très pertinent pour repérer des valeurs aberrantes, surtout dans ce cas, où il n'y a pas 
# vraiment de valeurs aberrantes, en effet un employé mécontent peut rester alors qu'un employé content partira
# pour d'autres raisons. Il faut donc regarder les autres colonnes et donc les autres relations possibles

# %%
g0 = sns.catplot(x="Attrition", y='TotalWorkingYears', data=ibm_hr_attrition, kind='bar')

# %%
# 5)
g = sns.boxplot(x="TotalWorkingYears", y='Attrition', data=ibm_hr_attrition)

# %%
g1 = sns.countplot(x='EducationField', data=df_attrition) #df_attrition =

# %%
# 6)
ibm_hr_attrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Visualisation d'une distribution
# 2)
# Avec distplot (déprécié): d = sns.displot(ibm_hr_attrition['MonthlyIncome'])
d = sns.displot(ibm_hr_attrition['MonthlyIncome'])

# %%
# 3)
df_attrition_low = pd.DataFrame(ibm_hr_attrition)
df_attrition_low = df_attrition_low[ df_attrition_low['MonthlyIncome']<5000 ]
d = sns.displot(df_attrition_low['MonthlyIncome'])

# %%
ibm_hr_attrition = pd.DataFrame(ibm_hr_attrition)
ibm_hr_attrition.replace({'Attrition': {'Yes':1, 'No':0}})
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Visualisation d'une relation linéaire
# 2)

g = sns.catplot(x="Attrition", y="DistanceFromHome", data=ibm_hr_attrition, kind='bar')
#sns.displot(ibm_hr_attrition, x="flipper_length_mm", hue="species", stat="probability")

# %%
set0 = ibm_hr_attrition.replace({'Attrition': {'Yes':1, 'No':0}})
sns.lmplot(x='DistanceFromHome', y='Attrition', data=set0)

# %%
sns.lmplot(x='YearsWithCurrManager', y='Attrition', data= set0)

# %%
lastColumn = ibm_hr_attrition.iloc[:,-15:].corr()

f, ax = plt.subplots(figsize=(20,5))
sns.heatmap(lastColumn, annot=True, ax =ax)
# Out:
# <AxesSubplot:>
