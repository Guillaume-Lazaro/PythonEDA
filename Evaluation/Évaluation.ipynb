# %%
# 1) Le KPI d'après ce que j'en comprends désigne l'analyse de points-clés de certaines données, notamment pour aider 
# les managers et chefs d'entreprise à piloter leur entreprise. En soi l'étude des KPI est faisable sur tous les registres
# (pas uniquement l'entreprise) le but est d'étudier quels sont les "indicateurs" clés d'un tableau de données et de les utiliser
# pour l'analyse

# %%
# 2)
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# 3)
resto = pd.read_csv('../data/resto_eval.csv')

# %%
# 4)
resto[:12]
# Out:
#     Unnamed: 0  order_id  quantity                              item_name  \
# 0            0         1         1           Chips and Fresh Tomato Salsa
# 1            1         1         1                                   Izze
# 2            2         1         1                       Nantucket Nectar
# 3            3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4            4         2         2                           Chicken Bowl
# 5            5         3         1                           Chicken Bowl
# 6            6         3         1                          Side of Chips
# 7            7         4         1                          Steak Burrito
# 8            8         4         1                       Steak Soft Tacos
# 9            9         5         1                          Steak Burrito
# 10          10         5         1                    Chips and Guacamole
# 11          11         6         1                   Chicken Crispy Tacos
#
# ...

# %%
# 5)
resto.shape
# Out:
# (4622, 6)

# %%
resto.size
# Out:
# 27732

# %%
# 6)
resto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  3376 non-null   object
#  5   item_price          4522 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
# Colonnes : un id, une quantité, le nom de l'objet en question, sa description 
# et enfin le prix de l'item

# %%
# 7)
resto.describe()
# Out:
#         Unnamed: 0     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       0.000000     1.000000     1.000000
# 25%    1155.250000   477.250000     1.000000
# 50%    2310.500000   926.000000     1.000000
# 75%    3465.750000  1393.000000     1.000000
# max    4621.000000  1834.000000    15.000000

# %%
# 8)
resto.groupby(['item_name']).sum().sort_values("quantity", ascending=False)
# Out:
#                                        Unnamed: 0  order_id  quantity
# item_name
# Chicken Bowl                              1779909    713926       761
# Chicken Burrito                           1238217    497303       591
# Chips and Guacamole                       1121773    449959       506
# Steak Burrito                              817795    328437       386
# Canned Soft Drink                          759990    304753       351
# Chips                                      518704    208004       230
# Steak Bowl                                 482721    193752       221
# Bottled Water                              439354    175944       211
# Chips and Fresh Tomato Salsa               250144    100419       130
# Canned Soda                                189915     76396       126
# Chicken Salad Bowl                         292292    117104       123
# Chicken Soft Tacos                         244891     98395       120
# ...

# %%
# L'item le plus commandé est donc le Chicken Bowl

# %%
# 9)
resto.groupby(['item_name']).sum()['quantity'].sum()
# Out:
# 4972

# %%
resto0 = resto.merge(unnamed, 'left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-3d73d6179616> in <module>
# ----> 1 resto0 = resto.merge(unnamed, 'left')
#
# NameError: name 'unnamed' is not defined

# %%
# 10)
resto_cleaned = resto.dropna()
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4              4         2         2                           Chicken Bowl
# ...          ...       ...       ...                                    ...
# 4617        4617      1833         1                          Steak Burrito
# 4618        4618      1833         1                          Steak Burrito
# 4619        4619      1834         1                     Chicken Salad Bowl
# 4620        4620      1834         1                     Chicken Salad Bowl
# 4621        4621      1834         1                     Chicken Salad Bowl
#
# ...

# %%
resto_sales = resto_cleaned['item_price'].replace('[\\$,]', '', regex=True).astype(float)
resto['total_price'] = resto_sales * resto['quantity']
resto
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4              4         2         2                           Chicken Bowl
# ...          ...       ...       ...                                    ...
# 4617        4617      1833         1                          Steak Burrito
# 4618        4618      1833         1                          Steak Burrito
# 4619        4619      1834         1                     Chicken Salad Bowl
# 4620        4620      1834         1                     Chicken Salad Bowl
# 4621        4621      1834         1                     Chicken Salad Bowl
#
# ...

# %%
# Ch

# %%
# 10 (11?))
# commands = resto.groupby(['order_id']).sum() # il y a eu 1834 commandes
# commands
# Out:
#           Unnamed: 0  quantity
# order_id
# 1                  6         4
# 2                  4         2
# 3                 11         2
# 4                 15         2
# 5                 19         2
# ...              ...       ...
# 1830            9221         2
# 1831           13839         3
# 1832            9231         2
# 1833            9235         2
# 1834           13860         3
#
# [1834 rows x 2 columns]
